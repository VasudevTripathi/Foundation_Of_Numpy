# %%
import numpy as np

# %%
marks = np.array([[78,85,90],[72,68,33],[99,24,56],[88,92,80],[65,84,69]])

# %%
print(marks.shape)
print(marks.ndim)
print(marks.size)
print(marks.dtype)
# Out:
# (5, 3)
# 2
# 15
# int64

# %%
print(marks[1:2])
print(marks[:,2])
print(marks[0,1])
# Out:
# [[72 68 33]]
# [90 33 56 80 69]
# 85

# %%
print(np.min(marks))
print(np.average(marks))
print(np.max(marks))
# Out:
# 24
# 72.2
# 99
