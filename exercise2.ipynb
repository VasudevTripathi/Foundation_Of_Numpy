# %%
import numpy as np

# %%
marks = np.array([[78,85,90],[72,68,33],[99,24,56],[88,92,80],[65,84,69]])

# %%
print(marks.shape)
print(marks.ndim)
print(marks.size)
print(marks.dtype)
# Out:
# (5, 3)
# 2
# 15
# int64
